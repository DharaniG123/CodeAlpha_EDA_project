# %%
import pandas as pd

data = {
    "Student": ["Asha", "Rahul", "Priya", "Arjun", "Meera"],
    "Age": [20, 22, 21, 23, 20],
    "Marks": [85, 90, 78, 88, 92]
}

df = pd.DataFrame(data)

df
# Out:
#   Student  Age  Marks
# 0    Asha   20     85
# 1   Rahul   22     90
# 2   Priya   21     78
# 3   Arjun   23     88
# 4   Meera   20     92

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  5 non-null      str
#  1   Age      5 non-null      int64
#  2   Marks    5 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 252.0 bytes

# %%
df.describe()
# Out:
#             Age      Marks
# count   5.00000   5.000000
# mean   21.20000  86.600000
# std     1.30384   5.458938
# min    20.00000  78.000000
# 25%    20.00000  85.000000
# 50%    21.00000  88.000000
# 75%    22.00000  90.000000
# max    23.00000  92.000000

# %%
df.isnull().sum()
# Out:
# Student    0
# Age        0
# Marks      0
# dtype: int64
